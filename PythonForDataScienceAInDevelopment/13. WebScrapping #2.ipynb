# %% [markdown]
# # Webscrapping using BeautifulSoup

# %% [markdown]
# Beautiful Soup is a Python library for pulling data out of HTML and XML files, we will focus on HTML files. This is accomplished by representing the HTML as a set of objects with methods used to parse the HTML.  We can navigate the HTML as a tree, and/or filter out what we are looking for.

# %%
from bs4 import BeautifulSoup
import requests

# %%
#store a html source code into a variable 
html = "<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3> \
<b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p> \
<h3>Stephen Curry</h3><p> Salary: $85,000,000</p> \
<h3>Kevin Durant</h3><p> Salary: $73,200,000</p></body></html>"
html
# Out:
# "<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3> <b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p> <h3>Stephen Curry</h3><p> Salary: $85,000,000</p> <h3>Kevin Durant</h3><p> Salary: $73,200,000</p></body></html>"

# %%
#to parse a document, pass into beautifulsoup constructor
#it object represents the document as a nested data structure

soup = BeautifulSoup(html, 'html5lib')
soup
# Out:
# <!DOCTYPE html>
# <html><head><title>Page Title</title></head><body><h3> <b id="boldest">Lebron James</b></h3><p> Salary: $ 92,000,000 </p> <h3>Stephen Curry</h3><p> Salary: $85,000,000</p> <h3>Kevin Durant</h3><p> Salary: $73,200,000</p></body></html>

# %% [markdown]
# First, the document is converted to Unicode (similar to ASCII) and HTML entities are converted to Unicode characters. Beautiful Soup transforms a complex HTML document into a complex tree of Python objects. The <code>BeautifulSoup</code> object can create other types of objects. In this lab, we will cover <code>BeautifulSoup</code> and <code>Tag</code> objects, that for the purposes of this lab are identical. Finally, we will look at <code>NavigableString</code> objects.

# %%
#display the HTML in the nested data structure
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html>\n <head>\n  <title>\n   Page Title\n  </title>\n </head>\n <body>\n  <h3>\n   <b id="boldest">\n    Lebron James\n   </b>\n  </h3>\n  <p>\n   Salary: $ 92,000,000\n  </p>\n  <h3>\n   Stephen Curry\n  </h3>\n  <p>\n   Salary: $85,000,000\n  </p>\n  <h3>\n   Kevin Durant\n  </h3>\n  <p>\n   Salary: $73,200,000\n  </p>\n </body>\n</html>\n'

# %% [markdown]
# ## Tag

# %% [markdown]
# The tag object corresponds to an HTML tag in the original document
# The tag object is a tree of obejcts
# Ex, the tag title correspond to html title

# %%
#The tag of title
tag_title = soup.title
print ("Tag object: ",tag_title)

#findout the type of tag
print (type(tag_title))

#if there is more than one tag with the same name,
#the first element with that tag name is called
tag_object = soup.h3
print(tag_object)

#This is a tree representation of HTML tag
# Out:
# Tag object:  <title>Page Title</title>
# <class 'bs4.element.Tag'>
# <h3> <b id="boldest">Lebron James</b></h3>

# %% [markdown]
# ## Children, Parents and Siblings

# %%
print(tag_object)

#we can know that the tag_object is h3
# Out:
# <h3> <b id="boldest">Lebron James</b></h3>

# %%
#we can access the tag or navigate down the branch as follows :

#access the tag_object child
tagChild = tag_object.b
print(tagChild)

#access the parent of tag_object's child
parentTag = tagChild.parent
print(parentTag) #and this is identical to tag_object itself
# Out:
# <b id="boldest">Lebron James</b>
# <h3> <b id="boldest">Lebron James</b></h3>

# %%
#access the tag_object (h3) parent, which is the body
print(tag_object.parent)
# Out:
# <body><h3> <b id="boldest">Lebron James</b></h3><p> Salary: $ 92,000,000 </p> <h3>Stephen Curry</h3><p> Salary: $85,000,000</p> <h3>Kevin Durant</h3><p> Salary: $73,200,000</p></body>

# %%
#access the sibling of tag_object (h3), which is the element that has the same level
sibling1 = tag_object.next_sibling
print(sibling1)

#sibling2 is a header, which is a sibling from sibling1
sibling2 = sibling1.next_sibling
print(sibling2)

#sibling3 is stephen curry, which is a sibling from sibling2
sibling3 = sibling2.next_sibling
print(sibling3)

#sibling4 is the salary of stephen curry
print (sibling3.next_sibling)
# Out:
# <p> Salary: $ 92,000,000 </p>
#
# <h3>Stephen Curry</h3>
# <p> Salary: $85,000,000</p>

# %% [markdown]
# ## HTML Attributes

# %% [markdown]
# If the tag has attributes, then :
# the tag <code> id = boldest </code>, has an attribute <code>id</code> whose value is <code>boldest</code>
# We can acces the tag's attributes by treating the tag like a dictionary

# %%
print(tagChild['id'])
print(tagChild.attrs)

print(tagChild.get('id'))
# Out:
# boldest
# {'id': 'boldest'}
# boldest

# %% [markdown]
# ## Navigable String

# %% [markdown]
# A string corresponds to a bit of text or content within a tag
# Beautifulsoup use <code>NavigableString</code> class to containt the string

# %%
print(tagChild)

tagChildString = tagChild.string
print(tagChildString)
print(type(tagChildString))

#we need to convert it into string, due to its class type
tagChildWord = str(tagChildString)
print(type(tagChildWord))
# Out:
# <b id="boldest">Lebron James</b>
# Lebron James
# <class 'bs4.element.NavigableString'>
# <class 'str'>

# %% [markdown]
# ## Filter

# %% [markdown]
# Filters allow the user to find a complex patterns, the simplest filter is a string.
# Now, we will pass a string to a different filter method and Beautifulsoup will perform a match against that exact string

# %%
#we put a html table to a table object

table = "<table><tr><td id='flight'>Flight No</td><td>Launch site</td> \
<td>Payload mass</td></tr><tr> <td>1</td> \
<td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a></td> \
<td>300 kg</td></tr><tr><td>2</td> \
<td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td> \
<td>94 kg</td></tr><tr><td>3</td> \
<td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td> \
<td>80 kg</td></tr></table>"

#then we will parse the table into the structured data structure by beautifulsoup
tableBs = BeautifulSoup(table, 'html5lib')

# %% [markdown]
# **Find All**

# %%
def head():
    print ("========")
    
#findall the tag name
tableRow = tableBs.find_all('tr')
print(tableRow)
head()

#and it is iterable like a list
print(tableRow[0])
head()

#we can also obtain its child, which is td
print(tableRow[0].td)
head()

#if we iterate it through the list, each element will corresponds to a row in a table
for i, row in enumerate(tableRow):
    print('row', i,'is', row)
head()

#as row is a cell object, we can apply method findall to it
#and extract table cells in the object "cells" using the tag "td"
#this is all the children with the name "td"
for i, row in enumerate(tableRow):
    print("Row",i)
    cells = row.find_all('td')
    for j, cell in enumerate(cells):
        print("Column",j ,"cell",cell)
head()

#we can also use a list that we can match against any item in that list
listInput = tableBs.find_all(name = ['tr','td'])
print(listInput)
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>, <tr> <td>1</td> <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td> <td>300 kg</td></tr>, <tr><td>2</td> <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td> <td>94 kg</td></tr>, <tr><td>3</td> <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td> <td>80 kg</td></tr>]
# ========
# <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>
# ========
# <td id="flight">Flight No</td>
# ========
# row 0 is <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>
# row 1 is <tr> <td>1</td> <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td> <td>300 kg</td></tr>
# row 2 is <tr><td>2</td> <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td> <td>94 kg</td></tr>
# row 3 is <tr><td>3</td> <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td> <td>80 kg</td></tr>
# ========
# Row 0
# Column 0 cell <td id="flight">Flight No</td>
# Column 1 cell <td>Launch site</td>
# Column 2 cell <td>Payload mass</td>
# Row 1
# Column 0 cell <td>1</td>
# Column 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td>
# Column 2 cell <td>300 kg</td>
# Row 2
# Column 0 cell <td>2</td>
# Column 1 cell <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>
# Column 2 cell <td>94 kg</td>
# Row 3
# Column 0 cell <td>3</td>
# Column 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td>
# Column 2 cell <td>80 kg</td>
# ========
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>, <td id="flight">Flight No</td>, <td>Launch site</td>, <td>Payload mass</td>, <tr> <td>1</td> <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td> <td>300 kg</td></tr>, <td>1</td>, <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td>, <td>300 kg</td>, <tr><td>2</td> <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td> <td>94 kg</td></tr>, <td>2</td>, <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>, <td>94 kg</td>, <tr><td>3</td> <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td> <td>80 kg</td></tr>, <td>3</td>, <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td>, <td>80 kg</td>]

# %% [markdown]
# ## Attributes

# %% [markdown]
# If the argument is not recognized, it will be turned into a filter on the tag's attributes.
#
# For example, with id argument, the beautifulsoup will filter against each tag's id attribute.
# Example. the first td elements have a value of id of flight, then we can filter based on that id value

# %%
tableBs.find_all(id = 'flight')
# Out:
# [<td id="flight">Flight No</td>]

# %%
#we also can find all the elements that have links to the florida wikipedia page:
listInput = tableBs.find_all(href= "https://en.wikipedia.org/wiki/Florida")
print(listInput)
head()

#if we set the href attribute to true, regardless of what value is
#the code finds all anchor tags with href value
print(tableBs.find_all('a', href=True))
head()

#in the other side, we can find all anchord tags without href value
print(tableBs.find_all('a',href=False))
head()

#using the object soup, we can find the element with the id attribute content set to boldest
print(soup.find_all(id='boldest'))
head()

#and lastly, with string, we can search for strings instead of tags
print(tableBs.find_all(string = 'Florida'))
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida</a>, <a href="https://en.wikipedia.org/wiki/Florida">Florida</a>]
# ========
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida</a>, <a href="https://en.wikipedia.org/wiki/Texas">Texas</a>, <a href="https://en.wikipedia.org/wiki/Florida">Florida</a>]
# ========
# [<a></a>, <a> </a>]
# ========
# [<b id="boldest">Lebron James</b>]
# ========
# ['Florida', 'Florida']

# %% [markdown]
# ## Find Two Tables Attributes

# %%
twoTb="<h3>Rocket Launch </h3> \
<p><table class='rocket'> \
<tr><td>Flight No</td><td>Launch site</td><td>Payload mass</td></tr> \
<tr><td>1</td><td>Florida</td><td>300 kg</td></tr> \
<tr><td>2</td><td>Texas</td><td>94 kg</td></tr> \
<tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table></p>\
<p><h3>Pizza Party</h3> \
<table class='pizza'> \
<tr><td>Pizza Place</td><td>Orders</td><td>Slices </td></tr> \
<tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr> \
<tr><td>Little Caesars</td><td>12</td><td >144 </td></tr> \
<tr><td>Papa John's</td><td>15 </td><td>165</td></tr>"

# %%
#then create a beautifulsoup object of twoTb object
tbBs = BeautifulSoup(twoTb, 'html.parser')

# %%
#we can find the first table using the tag name table
print(tbBs.find('table'))
head()

#we can also filter on the class atribute to find the second table
#cuz class is a syntax in python, we add _ to differentiate them
print(tbBs.find("table", class_="pizza"))
# Out:
# <table class="rocket"> <tr><td>Flight No</td><td>Launch site</td><td>Payload mass</td></tr> <tr><td>1</td><td>Florida</td><td>300 kg</td></tr> <tr><td>2</td><td>Texas</td><td>94 kg</td></tr> <tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table>
# ========
# <table class="pizza"> <tr><td>Pizza Place</td><td>Orders</td><td>Slices </td></tr> <tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr> <tr><td>Little Caesars</td><td>12</td><td>144 </td></tr> <tr><td>Papa John's</td><td>15 </td><td>165</td></tr></table>

# %% [markdown]
# # Download and Scrap the Contents of a Web Page IBM

# %%
#define the web page url to the object
url = "http://www.ibm.com"

# %%
#use "get" to download the contents of the webpage in text format
#and store it to data object
data = requests.get(url).text
data
# Out:
# '\n<!DOCTYPE HTML>\n<html lang="id-id">\n<head>\r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    <meta charset="UTF-8"/>\r\n    <meta name="languageCode" content="id"/>\r\n    <meta name="countryCode" content="id"/>\r\n    <meta name="searchTitle" content="IBM - Indonesia"/>\r\n    <meta name="focusArea" content="Cross IBM - All"/>\r\n    <title>IBM - Indonesia</title>\r\n    <link rel="icon" href="/content/dam/adobe-cms/default-images/favicon.svg"/>\r\n    \r\n    <meta name="description" content="Selama lebih dari satu abad, IBM telah menjadi inovator teknologi global, yang memimpin kemajuan dalam AI, otomatisasi, dan solusi hybrid cloud yang membantu pertumbuhan bisnis."/>\r\n    <meta name="template" content="full-width-layout"/>\r\n    <meta name="viewport" content="width=device-width, initial-scale=1"/>\r\n    <meta name="robots" content="index, follow"/>\r\n    \r\n      \r\n      \r\n    <link rel="canonical" href="https://www.ibm.com/id-id"/>\r\n    <style id="anti-flicker-style">\r\n        :not(:defined) {\r\n          visibility: hidden;\r\n        }\r\n    </style>\r\n    <!--<script type="text/javascript" id="anti-flicker-script">\r\n        (async () => {\r\n          await customElements.whenDefined(\'dds-masthead-container\');\r\n          document.getElementById(\'anti-flicker-style\').remove();\r\n          document.getElementById(\'anti-flicker-script\').remove();\r\n        })()\r\n    </script>-->\r\n    \r\n\r\n    <script type="text/javascript">\r\n        window.searchKey = {\r\n            templateName: \'full\\u002Dwidth\\u002Dlayout\',\r\n            taxonomylist: \'\',\r\n            L0Tag: \'Topics,Brands,Industries,Geography,Compliance Entities,Products,Events,Computer Languages,Content Format,Series,Content Type,CMaaS Focus Areas\',\r\n        }\r\n    </script>\r\n\r\n    \r\n        <link rel="alternate" hreflang="de-de" href="https://www.ibm.com/de-de"/>\r\n    \r\n        <link rel="alternate" hreflang="en-us" href="https://www.ibm.com/"/>\r\n    \r\n        <link rel="alternate" hreflang="en-ca" href="https://www.ibm.com/ca-en"/>\r\n    \r\n        <link rel="alternate" hreflang="ko-kr" href="https://www.ibm.com/kr-ko"/>\r\n    \r\n        <link rel="alternate" hreflang="pt-br" href="https://www.ibm.com/br-pt"/>\r\n    \r\n        <link rel="alternate" hreflang="en-in" href="https://www.ibm.com/in-en"/>\r\n    \r\n        <link rel="alternate" hreflang="es-es" href="https://www.ibm.com/es-es"/>\r\n    \r\n        <link rel="alternate" hreflang="zh-cn" href="https://www.ibm.com/cn-zh"/>\r\n    \r\n        <link rel="alternate" hreflang="es-mx" href="https://www.ibm.com/mx-es"/>\r\n    \r\n        <link rel="alternate" hreflang="fr-ca" href="https://www.ibm.com/ca-fr"/>\r\n    \r\n        <link rel="alternate" hreflang="it-it" href="https://www.ibm.com/it-it"/>\r\n    \r\n        <link rel="alternate" hreflang="id-id" href="https://www.ibm.com/id-id"/>\r\n    \r\n        <link rel="alternate" hreflang="en-au" href="https://www.ibm.com/au-en"/>\r\n    \r\n        <link rel="alternate" hreflang="en-uk" href="https://www.ibm.com/uk-en"/>\r\n    \r\n        <link rel="alternate" hreflang="fr-fr" href="https://www.ibm.com/fr-fr"/>\r\n    \r\n        <link rel="alternate" hreflang="ja-jp" href="https://www.ibm.com/jp-ja"/>\r\n    \r\n    <script type="text/javascript">\r\n        window.antiFlicker = {\r\n            active: true,\r\n            timeout: 3000\r\n        }\r\n    </script>\r\n    <script type="text/javascript">\r\n        var languageCode = document.getElementsByName(\'languageCode\')[0].content;\r\n        var countryCode = document.getElementsByName(\'countryCode\')[0].content;\r\n        var focusArea = document.getElementsByName(\'focusArea\')[0].content;\r\n        /* Define digital data object based on _appInfo object */\r\n        window.digitalData = {\r\n            page: {\r\n                category: {\r\n                    primaryCategory: \'\',\r\n        ...

# %%
#then, create a beautifulsoup object using its constructor
soup = BeautifulSoup(data, 'html5lib')
soup
# Out:
# <!DOCTYPE html>
# <html lang="id-id"><head>
#
#
#
#
#
#
#
#     <meta charset="utf-8"/>
#     <meta content="id" name="languageCode"/>
#     <meta content="id" name="countryCode"/>
#     <meta content="IBM - Indonesia" name="searchTitle"/>
#     <meta content="Cross IBM - All" name="focusArea"/>
#     <title>IBM - Indonesia</title>
#     <link href="/content/dam/adobe-cms/default-images/favicon.svg" rel="icon"/>
#
#     <meta content="Selama lebih dari satu abad, IBM telah menjadi inovator teknologi global, yang memimpin kemajuan dalam AI, otomatisasi, dan solusi hybrid cloud yang membantu pertumbuhan bisnis." name="description"/>
#     <meta content="full-width-layout" name="template"/>
#     <meta content="width=device-width, initial-scale=1" name="viewport"/>
#     <meta content="index, follow" name="robots"/>
#
#
#
#     <link href="https://www.ibm.com/id-id" rel="canonical"/>
#     <style id="anti-flicker-style">
#         :not(:defined) {
#           visibility: hidden;
#         }
#     </style>
#     <!--<script type="text/javascript" id="anti-flicker-script">
#         (async () => {
#           await customElements.whenDefined('dds-masthead-container');
#           document.getElementById('anti-flicker-style').remove();
#           document.getElementById('anti-flicker-script').remove();
#         })()
#     </script>-->
#
#
#     <script type="text/javascript">
#         window.searchKey = {
#             templateName: 'full\u002Dwidth\u002Dlayout',
#             taxonomylist: '',
#             L0Tag: 'Topics,Brands,Industries,Geography,Compliance Entities,Products,Events,Computer Languages,Content Format,Series,Content Type,CMaaS Focus Areas',
#         }
#     </script>
#
#
#         <link href="https://www.ibm.com/de-de" hreflang="de-de" rel="alternate"/>
#
#         <link href="https://www.ibm.com/" hreflang="en-us" rel="alternate"/>
#
#         <link href="https://www.ibm.com/ca-en" hreflang="en-ca" rel="alternate"/>
#
#         <link href="https://www.ibm.com/kr-ko" hreflang="ko-kr" rel="alternate"/>
#
#         <link href="https://www.ibm.com/br-pt" hreflang="pt-br" rel="alternate"/>
#
#         <link href="https://www.ibm.com/in-en" hreflang="en-in" rel="alternate"/>
#
#         <link href="https://www.ibm.com/es-es" hreflang="es-es" rel="alternate"/>
#
#         <link href="https://www.ibm.com/cn-zh" hreflang="zh-cn" rel="alternate"/>
#
#         <link href="https://www.ibm.com/mx-es" hreflang="es-mx" rel="alternate"/>
#
#         <link href="https://www.ibm.com/ca-fr" hreflang="fr-ca" rel="alternate"/>
#
#         <link href="https://www.ibm.com/it-it" hreflang="it-it" rel="alternate"/>
#
#         <link href="https://www.ibm.com/id-id" hreflang="id-id" rel="alternate"/>
#
#         <link href="https://www.ibm.com/au-en" hreflang="en-au" rel="alternate"/>
#
#         <link href="https://www.ibm.com/uk-en" hreflang="en-uk" rel="alternate"/>
#
#         <link href="https://www.ibm.com/fr-fr" hreflang="fr-fr" rel="alternate"/>
#
#         <link href="https://www.ibm.com/jp-ja" hreflang="ja-jp" rel="alternate"/>
#
#     <script type="text/javascript">
#         window.antiFlicker = {
#             active: true,
#             timeout: 3000
#         }
#     </script>
#     <script type="text/javascript">
#         var languageCode = document.getElementsByName('languageCode')[0].content;
#         var countryCode = document.getElementsByName('countryCode')[0].content;
#         var focusArea = document.getElementsByName('focusArea')[0].content;
#         /* Define digital data object based on _appInfo object */
#         window.digitalData = {
#             page: {
#                 category: {
#                     primaryCategory: '',
#                 },
#                 pageInfo: {
#                     language: languageCode + '-' + countryCode,
#                     ibm: {
#                         siteID: 'MarketingAEM',
#                         country: countryCode,
#                         messaging: {
#                             routing: {
#                                 focusArea: focusArea,
#                                 languageCode: languageCode,
#                                 regionCode: countryCode
#                             },
#                             translation: {
#                                 languageCode: languageCode,
#                                 regionCode: countryCode
#                             }
#                         },
#                         sections: 0,
#                         patterns: 0,
#                     },
#                     carbon: {
#                         '@carbon/web-components': 'v1.40.0',
#                         '@carbon/ibmdotcom-web-components': 'v1.44.0',
#                         'carbon-for-aem': 'v0.13.1',
#                     },
#                 },
#             },
#         };
#     </script>
#
#
#         <meta content="https://www.ibm.com/id-id" property="og:url"/>
#
#         <meta content="website" property="og:type"/>
#
#         <meta content="IBM - Indonesia" property="og:title"/>
#
#         <meta content="Selama lebih dari satu abad, IBM telah menjadi inovator teknologi global, yang memimpin kemajuan dalam AI, otomatisasi, dan solusi hybrid cloud yang membantu pertumbuhan bisnis." property="og:description"/>
#
#         <meta content="https://www.ibm.com/content/dam/connectedassets-adobe-cms/worldwide-content/cdp/cf/ul/g/a6/c8/codb-2023-leadspace-r1v1.jpg/_jcr_content/renditions/cq5dam.web.1280.1280.jpeg" property="og:image"/>
#
#
#
#
#     <script async="async" src="https://1.www.s81c.com/common/stats/ibm-common.js" type="text/javascript"></script>
#     <script src="https://hybrid-cloud-widgets-production.s3.us.cloud-object-storage.appdomain.cloud/loader.js" type="application/javascript"></script>
#
#
#
#
# <link href="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlStylesCarbon.lc-cf922a17b2cb010a999f418ad07792fa-lc.min.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlStyles.lc-8370c4eff24eb5aca8d5776d7e7a0d97-lc.min.css" rel="stylesheet" type="text/css"/>
#
#
#
#
#
#         <link href="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/tag/v1/latest/plex.css" rel="stylesheet"/>
#         <link href="https://1.www.s81c.com/common/carbon/plex/sans.css" rel="stylesheet"/>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </head>
# <body class="content-page page basicpage publish" id="content-page-86fceee77e">
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="root container responsivegrid">
#
#
#
#
#     <div class="cmp-container" id="container-9225520bd9">
#
#         <div class="masthead">
#
#
#
#
#
#
#
# <dds-masthead-container auth-method="profile-api" data-endpoint="/common/carbon-for-ibm-dotcom/translations/masthead-footer/v2.1" has-contact="true"></dds-masthead-container>
# <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/2.0.0.alpha.9164247689/masthead.min.js" type="module"></script>
#
#
#
#
#
#
# <script type="text/javascript">
#     if(window.location.href.includes("/careers")){
#        document.querySelector('dds-masthead-container').setAttribute("has-search","false");
#        document.querySelector('dds-masthead-container').setAttribute("has-profile","false");
#     }
# </script></div>
# <div class="leadspace-container container responsivegrid">
#
#
#
#
#     <div class="cmp-container" id="leadspace-container-66dd6c07c8">
#
#         <div class="leadspace-expanded leadspace">
# <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.13.1/star-rating.min.js" type="module"></script>
#
#
#
# <section class="theme-white">
#     <dds-video-cta-container>
#         <caem-container-leadspace size="tall">
#
#
#
#
#             <caem-heading id="leadspaceSimpleTitle" slot="heading" type="h1" type-style="display-01">
#
#
#
#   <dds-content-group-heading>
#
#
#
#
# <span class="enhanced-title">Percayalah pada perjalanan AI Anda</span>
#
#
#
#
#
#   </dds-content-group-heading>
#
#
#
#
#
#
#
#
#
#             </caem-heading>
#
#             <caem-paragraph data-autoid="caem--paragraph" size="lead-in">
#
#                     <p>
#
#
#
#
#       Di Think 2024, transparansi AI adalah hal terpenting dalam AI generatif. Pelajari cara IBM dapat mendukung perjalanan AI Anda.
#
#
#
#
#
#
#
# </p>
#
#             </caem-paragraph>
#
#
#                 <caem-button-group slot="action">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <caem-button-cta cta-type="local" data-aem-autoid="aem--leadspace_cta-0" href="https://www.ibm.com/impact/ai-ethics?lnk=hpIDls1" kind="primary" target="_blank">
#         <span>Bangun kepercayaan dengan etika AI</span>
#
#
#     </caem-button-cta>
#
#
#
#
#
#
#
#
#
#     <caem-button-cta cta-type="local" data-aem-autoid="aem--leadspace_cta-1" href="https://www.ibm.com/id-id/products/watsonx-governance" kind="tertiary" target="_blank">
#         <span>Jelajahi watsonx.governance</span>
#
#
#     </caem-button-cta>
#
#
#
#
#
#
#
#
#                 </caem-button-group>
#
#
#
#
#
#
#
#
#
#
#
#
#         <caem-image-with-caption alt="Percayalah pada perjalanan AI Anda logo" caption-alignment="left" class="" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/55/14/watsonx-governance_dco-native.component.crop-5by4-xl.ts=1718313925453.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/leadspace_container/leadspace_expanded" id="image--1817185192" slot="media">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/55/14/watsonx-governance_dco-native.component.crop-5by4-xl-retina.ts=1718313925453.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/55/14/watsonx-governance_dco-native.component.crop-5by4-xl.ts=1718313925453.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/55/14/watsonx-governance_dco-native.component.crop-5by4-l-retina.ts=1718313925453.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/55/14/watsonx-governance_dco-native.component.crop-5by4-l.ts=1718313925453.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/55/14/watsonx-governance_dco-native.component.crop-5by4-m-retina.ts=1718313925453.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/55/14/watsonx-governance_dco-native.component.crop-5by4-m.ts=1718313925453.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/55/14/watsonx-governance_dco-native.component.crop-5by4-s-retina.ts=1718313925453.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/55/14/watsonx-governance_dco-native.component.crop-5by4-s.ts=1718313925453.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/55/14/watsonx-governance_dco-native.component.crop-5by4-xs-retina.ts=1718313925453.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/pm/ul/g/55/14/watsonx-governance_dco-native.component.crop-5by4-xs.ts=1718313925453.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/leadspace_container/leadspace_expanded"></dds-image-item>
#
#
#
#
#
#         </caem-image-with-caption>
#
#
#
#
#
#
#
#
#
#
#
#
#                         <dds-link-list slot="aside">
#                             <dds-link-list-heading aria-level="4" role="heading" slot="heading">
#
#
#
#
#
#       Berita Terbaru
#
#
#
#
#
#
#
#
#                             </dds-link-list-heading>
#
#
#
#
#
#
#                 <caem-link-list-item cta-type="local" href="https://www.ibm.com/events/reg/flow/ibm/g5oxq8mb/landing/page/landing?utm_medium=Email&amp;utm_source=Event&amp;utm_content=WTXWW&amp;utm_term=20AQR&amp;utm_campaign=PLACEHOLDER&amp;utm_id=ibm.com" label="Event | 25 Juli " target="_blank">
#
#
#
#
#
#
#
#
#
#                     <p>AI for Business "Navigating the Future of Insurance in the Era of AI" </p>
#
#                     <dds-card-cta-footer cta-type="local" href="https://www.ibm.com/events/reg/flow/ibm/g5oxq8mb/landing/page/landing?utm_medium=Email&amp;utm_source=Event&amp;utm_content=WTXWW&amp;utm_term=20AQR&amp;utm_campaign=PLACEHOLDER&amp;utm_id=ibm.com" target="_blank">
#
#                     </dds-card-cta-footer>
#                 </caem-link-list-item>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 <caem-link-list-item cta-type="local" href="https://asean.newsroom.ibm.com/IBM-Consulting-Indonesia-empowers-businesses-unlock-the-power-of-generative-AI" label="IBM Consulting " target="_blank">
#
#
#
#
#
#
#
#
#
#                     <p>Berdayakan dunia usaha untuk membuka kekuatan AI generatif</p>
#
#                     <dds-card-cta-footer cta-type="local" href="https://asean.newsroom.ibm.com/IBM-Consulting-Indonesia-empowers-businesses-unlock-the-power-of-generative-AI" target="_blank">
#
#                     </dds-card-cta-footer>
#                 </caem-link-list-item>
#
#
#
#
#
#
#
#
#
#
#
#
#                         </dds-link-list>
#
#
#
#
#
#
#         </caem-container-leadspace>
#     </dds-video-cta-container>
# </section>
#
#
#
#
#
# </div>
#
#
#     </div>
#
# </div>
# <div class="table-of-contents container responsivegrid">
# <dds-table-of-contents class="cmp-table-of-contents" data-autoid="dds--table-of-contents" data-cmp-is="table-of-contents" stickyoffset="48" toc-hide="hidden" toc-layout="horizontal">
#
#
#     <div class="cmp-table-of-contents" id="table-of-contents-c9dc783614">
#
#         <div class="modular-container container responsivegrid">
#
#
#
#
#     <div class="cmp-container" id="modular-container-d07b0d5ca7">
#
#         <div class="standalone-title enhanced-title text">
#
#
#
# <caem-heading type="h5">Rekomendasi untuk Anda</caem-heading>
#
#
#
# </div>
#
#
#     </div>
#
# </div>
# <div class="tile-group-container container responsivegrid">
#   <div class="bx--col">
#
#
#
#
# <caem-heading type="h2"></caem-heading>
#
#
#
#
#     <caem-tile-group>
#
#
#
#
#     <caem-tile cta-type="local" href="https://www.ibm.com/thought-leadership/institute-business-value/report/ceo-generative-ai?lnk=cardT" label="Laporan IBV" target="_self">
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image alt="Ilustrasi bentuk Bumi biru" class="" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/13/fd/the-ceos-guide-to-generative-ai-desktop.component.tile-card-xl.ts=1717607040682.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image" id="image-228656773" slot="image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/13/fd/the-ceos-guide-to-generative-ai-desktop.component.tile-card-xl-retina.ts=1717607040682.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/13/fd/the-ceos-guide-to-generative-ai-desktop.component.tile-card-xl.ts=1717607040682.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/13/fd/the-ceos-guide-to-generative-ai-desktop.component.tile-card-l-retina.ts=1717607040682.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/13/fd/the-ceos-guide-to-generative-ai-desktop.component.tile-card-l.ts=1717607040682.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/13/fd/the-ceos-guide-to-generative-ai-desktop.component.tile-card-m-retina.ts=1717607040682.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/13/fd/the-ceos-guide-to-generative-ai-desktop.component.tile-card-m.ts=1717607040682.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/13/fd/the-ceos-guide-to-generative-ai-desktop.component.tile-card-s-retina.ts=1717607040682.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/13/fd/the-ceos-guide-to-generative-ai-desktop.component.tile-card-s.ts=1717607040682.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/13/fd/the-ceos-guide-to-generative-ai-desktop.component.tile-card-xs-retina.ts=1717607040682.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/13/fd/the-ceos-guide-to-generative-ai-desktop.component.tile-card-xs.ts=1717607040682.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card/image"></dds-image-item>
#
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#
#
#
#         Panduan CEO untuk AI Generatif
#
#
#
#
#
#
#
#
#
#         <p slot="cta">
#
#         </p>
#
#     </caem-tile>
#
#     <div class="caem-card-svg-source" hidden="">
#         <svg id="accelerated-computing" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"></path></svg>
#     </div>
#
#
#
#
#
#
#
#
#
#     <caem-tile cta-type="local" href="https://www.ibm.com/thought-leadership/institute-business-value/report/ceo-generative-ai/talent-skills?lnk=hpIDrc1" label="Kepemimpinan pemikiran" target="_self">
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image alt="Tumpukan buku AI generatif" class="" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibv/ul/g/19/fb/1235_generative_ai_book_leadspace_3168x1470.component.tile-card-xl.ts=1717642195993.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image" id="image-1203979798" slot="image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibv/ul/g/19/fb/1235_generative_ai_book_leadspace_3168x1470.component.tile-card-xl-retina.ts=1717642195993.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibv/ul/g/19/fb/1235_generative_ai_book_leadspace_3168x1470.component.tile-card-xl.ts=1717642195993.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibv/ul/g/19/fb/1235_generative_ai_book_leadspace_3168x1470.component.tile-card-l-retina.ts=1717642195993.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibv/ul/g/19/fb/1235_generative_ai_book_leadspace_3168x1470.component.tile-card-l.ts=1717642195993.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibv/ul/g/19/fb/1235_generative_ai_book_leadspace_3168x1470.component.tile-card-m-retina.ts=1717642195993.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibv/ul/g/19/fb/1235_generative_ai_book_leadspace_3168x1470.component.tile-card-m.ts=1717642195993.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibv/ul/g/19/fb/1235_generative_ai_book_leadspace_3168x1470.component.tile-card-s-retina.ts=1717642195993.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibv/ul/g/19/fb/1235_generative_ai_book_leadspace_3168x1470.component.tile-card-s.ts=1717642195993.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibv/ul/g/19/fb/1235_generative_ai_book_leadspace_3168x1470.component.tile-card-xs-retina.ts=1717642195993.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/ibv/ul/g/19/fb/1235_generative_ai_book_leadspace_3168x1470.component.tile-card-xs.ts=1717642195993.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2105644765/image"></dds-image-item>
#
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#
#
#
#         AI menghadirkan batas baru bagi masa depan dunia kerja
#
#
#
#
#
#
#
#
#
#         <p slot="cta">
#
#         </p>
#
#     </caem-tile>
#
#     <div class="caem-card-svg-source" hidden="">
#         <svg id="accelerated-computing" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"></path></svg>
#     </div>
#
#
#
#
#
#
#
#
#
#     <caem-tile cta-type="local" href="https://www.ibm.com/account/reg/signup?formid=news-urx-51525" label="Berlangganan" target="_self">
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image alt="Ilustrasi pengiriman email" class="" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/gbs/cf/ul/g/ad/f6/304x304-b.component.tile-card-xl.ts=1716429072707.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image" id="image--862193196" slot="image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/gbs/cf/ul/g/ad/f6/304x304-b.component.tile-card-xl-retina.ts=1716429072707.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/gbs/cf/ul/g/ad/f6/304x304-b.component.tile-card-xl.ts=1716429072707.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/gbs/cf/ul/g/ad/f6/304x304-b.component.tile-card-l-retina.ts=1716429072707.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/gbs/cf/ul/g/ad/f6/304x304-b.component.tile-card-l.ts=1716429072707.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/gbs/cf/ul/g/ad/f6/304x304-b.component.tile-card-m-retina.ts=1716429072707.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/gbs/cf/ul/g/ad/f6/304x304-b.component.tile-card-m.ts=1716429072707.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/gbs/cf/ul/g/ad/f6/304x304-b.component.tile-card-s-retina.ts=1716429072707.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/gbs/cf/ul/g/ad/f6/304x304-b.component.tile-card-s.ts=1716429072707.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/gbs/cf/ul/g/ad/f6/304x304-b.component.tile-card-xs-retina.ts=1716429072707.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/gbs/cf/ul/g/ad/f6/304x304-b.component.tile-card-xs.ts=1716429072707.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_392377621/image"></dds-image-item>
#
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#
#
#
#         Dapatkan wawasan teknologi dan bisnis dalam buletin IBM
#
#
#
#
#
#
#
#
#
#         <p slot="cta">
#
#         </p>
#
#     </caem-tile>
#
#     <div class="caem-card-svg-source" hidden="">
#         <svg id="accelerated-computing" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"></path></svg>
#     </div>
#
#
#
#
#
#
#
#
#
#     <caem-tile cta-type="local" href="https://www.ibm.com/id-id/products/offers-and-discounts" label="Penawaran dan diskon" target="_self">
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image alt="Grafik pembaruan otomatis" class="" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/26/25/discount-time-to-renewal-illustration.component.tile-card-xl.ts=1716470397473.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image" id="image-941724913" slot="image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/26/25/discount-time-to-renewal-illustration.component.tile-card-xl-retina.ts=1716470397473.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/26/25/discount-time-to-renewal-illustration.component.tile-card-xl.ts=1716470397473.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/26/25/discount-time-to-renewal-illustration.component.tile-card-l-retina.ts=1716470397473.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/26/25/discount-time-to-renewal-illustration.component.tile-card-l.ts=1716470397473.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/26/25/discount-time-to-renewal-illustration.component.tile-card-m-retina.ts=1716470397473.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/26/25/discount-time-to-renewal-illustration.component.tile-card-m.ts=1716470397473.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/26/25/discount-time-to-renewal-illustration.component.tile-card-s-retina.ts=1716470397473.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/26/25/discount-time-to-renewal-illustration.component.tile-card-s.ts=1716470397473.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/26/25/discount-time-to-renewal-illustration.component.tile-card-xs-retina.ts=1716470397473.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/26/25/discount-time-to-renewal-illustration.component.tile-card-xs.ts=1716470397473.png/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_1699798462/image"></dds-image-item>
#
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#
#
#
#         Hemat pada produk IBM tertentu sekarang juga
#
#
#
#
#
#
#
#
#
#         <p slot="cta">
#
#         </p>
#
#     </caem-tile>
#
#     <div class="caem-card-svg-source" hidden="">
#         <svg id="accelerated-computing" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"></path></svg>
#     </div>
#
#
#
#
#
#
#
#
#
#
#     </caem-tile-group>
#   </div>
#
#
#
# </div>
# <div class="intro-section">
# <div class="bx--col">
#     <caem-intro-section>
#
#         <caem-heading data-autoid="caem-heading" slot="heading" type="h2" type-style="expressive-heading-05">
#
#
#
#
#
#     Telusuri teknologi kami
#
#
#
#
#
#
#
#
#
#         </caem-heading>
#
#         <caem-paragraph data-autoid="caem--paragraph" size="lead-in">
#             <div class="cms-richtext" data-dynamic-inner-content="description" id="rich-text-807568c58c">
#     <p>Dari produk unggulan kami untuk <a href="https://www.ibm.com/cloud?lnk=intro">infrastruktur hybrid cloud</a> perusahaan hingga AI generasi berikutnya, solusi keamanan dan penyimpanan, temukan jawaban atas tantangan bisnis Anda.</p>
#
#
#
#
#
#
# </div>
#         </caem-paragraph>
#
#
#             <dds-link-list type="vertical">
#
#
#
#
#
#
#         <dds-video-cta-container>
#             <dds-link-list-item-cta cta-type="local" href="https://www.ibm.com/products?lnk=intro" icon-placement="right" role="listitem" target="_self">
#                 Lihat semua produk
#
#             </dds-link-list-item-cta>
#         </dds-video-cta-container>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             </dds-link-list>
#
#
#
#
#     </caem-intro-section>
# </div>
#
#
#
#
#
#
# </div>
# <div class="card-group-pictogram-full-width card-group-pictogram">
#     <div class="bx--content-block">
#
#
#
#
#
#                 <caem-card-group cards-per-row="4" data-autoid="dds--card-group" grid-mode="border" style="--dds--card-group--cards-in-row:4">
#
#
#
#
#
#
#
#
#
#
#
#                 <caem-card color-scheme="" cta-type="local" data-autoid="caem--card" href="https://www.ibm.com/artificial-intelligence?lnk=prodC" pictogram-placement="top" size="" target="_self">
#                     <caem-card-heading aria-level="3" data-autoid="caem--card-heading" role="heading" slot="heading">
#
#                         AI &amp; machine learning</caem-card-heading>
#                     <svg class="bx--card__pictogram" data-autoid="caem--card__pictogram" focusable="false" height="48" role="img" slot="pictogram" width="48">
#                         <use href="#ai"></use>
#                     </svg>
#                     <p>Gunakan AI IBM Watsonx atau bangun model machine learning Anda sendiri</p>
#                     <caem-card-cta-footer color-scheme="" cta-type="local" data-autoid="caem--card-cta-footer" href="https://www.ibm.com/artificial-intelligence?lnk=prodC" icon-placement="right" parent-href="https://www.ibm.com/artificial-intelligence?lnk=prodC" slot="footer" target="_self">
#
#                     </caem-card-cta-footer>
#                     <div class="caem-card-svg-source">
#                         <svg id="ai" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M16.195,31.36c-6.421,0-12.169-4.007-14.399-10.002 C1.051,21.408,0.373,20.771,0.372,20c0-0.75,0.61-1.36,1.36-1.36s1.36,0.61,1.36,1.36c0,0.474-0.243,0.892-0.611,1.135 c2.133,5.698,7.604,9.505,13.714,9.505c6.446,0,11.919-4.301,13.773-10.22c-1.448,2.06-3.877,3.44-6.565,3.44 c-3.822,0-7.066-2.785-7.664-6.525C15.113,17.212,14.64,16.661,14.64,16c0-0.584,0.37-1.083,0.888-1.275 c-0.608-3.421-3.615-5.962-7.125-5.962c-3.947,0-7.04,3.176-7.042,7.231c0,0.002,0,0.004,0,0.006H0.64c0-0.002,0-0.004,0-0.007 C0.644,7.526,7.445,0.64,15.805,0.64c6.42,0,12.168,4.006,14.399,10.001c0.777-0.034,1.425,0.587,1.425,1.358 c0,0.75-0.61,1.36-1.36,1.36s-1.36-0.61-1.36-1.36c0-0.473,0.243-0.891,0.611-1.135C27.387,5.166,21.916,1.36,15.805,1.36 c-6.319,0-11.704,4.134-13.659,9.873c1.402-1.949,3.662-3.19,6.256-3.19c3.881,0,7.204,2.826,7.846,6.62 C16.88,14.779,17.36,15.335,17.36,16c0,0.589-0.376,1.092-0.901,1.28c0.567,3.363,3.496,5.859,6.943,5.859 c3.857,0,7.127-3.118,7.235-6.851c0.001-0.096,0.002-0.192,0.002-0.289h0.721c0,0.033,0,0.065-0.001,0.098h0.001 c0,0.069-0.001,0.138-0.003,0.207C31.196,24.634,24.456,31.36,16.195,31.36z M1.732,19.36c-0.353,0-0.64,0.287-0.64,0.64 s0.287,0.64,0.64,0.64s0.64-0.287,0.64-0.64S2.085,19.36,1.732,19.36z M16,15.36c-0.353,0-0.64,0.287-0.64,0.64 s0.287,0.64,0.64,0.64s0.64-0.287,0.64-0.64S16.353,15.36,16,15.36z M30.269,11.36c-0.353,0-0.64,0.287-0.64,0.64 s0.287,0.64,0.64,0.64s0.64-0.287,0.64-0.64S30.621,11.36,30.269,11.36z"></path></svg>
#                     </div>
#                 </caem-card>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 <caem-card color-scheme="" cta-type="local" data-autoid="caem--card" href="https://www.ibm.com/analytics?lnk=ProdC" pictogram-placement="top" size="" target="_self">
#                     <caem-card-heading aria-level="3" data-autoid="caem--card-heading" role="heading" slot="heading">
#
#                         Analisis</caem-card-heading>
#                     <svg class="bx--card__pictogram" data-autoid="caem--card__pictogram" focusable="false" height="48" role="img" slot="pictogram" width="48">
#                         <use href="#predictive-analytics"></use>
#                     </svg>
#                     <p>Menggabungkan dan menganalisis kumpulan data besar</p>
#                     <caem-card-cta-footer color-scheme="" cta-type="local" data-autoid="caem--card-cta-footer" href="https://www.ibm.com/analytics?lnk=ProdC" icon-placement="right" parent-href="https://www.ibm.com/analytics?lnk=ProdC" slot="footer" target="_self">
#
#                     </caem-card-cta-footer>
#                     <div class="caem-card-svg-source">
#                         <svg id="predictive-analytics" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M31,31.36H1c-0.199,0-0.36-0.161-0.36-0.36 V1h0.72v29.64h4.28v-7.328c-0.576-0.158-1-0.687-1-1.312c0-0.75,0.61-1.36,1.36-1.36c0.364,0,0.694,0.144,0.938,0.377l3.702-2.221 v-8.484c-0.576-0.158-1-0.686-1-1.312c0-0.75,0.61-1.36,1.36-1.36S12.36,8.25,12.36,9c0,0.625-0.424,1.153-1,1.312v8.053l3.33-1.998 c-0.032-0.116-0.05-0.239-0.05-0.366c0-0.75,0.61-1.36,1.36-1.36c0.364,0,0.695,0.144,0.939,0.377l3.701-2.221V6.312 c-0.575-0.158-1-0.686-1-1.312c0-0.75,0.61-1.36,1.36-1.36S22.36,4.25,22.36,5c0,0.625-0.425,1.153-1,1.312v6.053l3.33-1.998 c-0.033-0.117-0.05-0.24-0.05-0.367c0-0.75,0.61-1.36,1.36-1.36s1.36,0.61,1.36,1.36c0,0.625-0.425,1.153-1,1.312V30.64H31V31.36z M21.36,30.64h4.279V11.312c-0.22-0.061-0.418-0.175-0.578-0.328l-3.701,2.221V30.64z M16.36,30.64h4.28V13.636l-3.33,1.998 c0.033,0.116,0.05,0.239,0.05,0.366c0,0.625-0.425,1.153-1,1.312V30.64z M11.36,30.64h4.28V17.312 c-0.22-0.061-0.418-0.175-0.579-0.328l-3.702,2.221V30.64H11.36z M6.36,30.64h4.28V19.636l-3.33,1.998 C7.343,21.75,7.36,21.873,7.36,22c0,0.625-0.424,1.153-1,1.312V30.64z M6,21.36c-0.353,0-0.64,0.287-0.64,0.64S5.647,22.64,6,22.64 S6.64,22.353,6.64,22S6.353,21.36,6,21.36z M16,15.36c-0.353,0-0.64,0.287-0.64,0.64s0.287,0.64,0.64,0.64s0.64-0.287,0.64-0.64 S16.353,15.36,16,15.36z M26,9.36c-0.353,0-0.64,0.287-0.64,0.64s0.287,0.64,0.64,0.64s0.64-0.287,0.64-0.64S26.353,9.36,26,9.36z M11,8.36c-0.353,0-0.64,0.287-0.64,0.64S10.647,9.64,11,9.64S11.64,9.353,11.64,9S11.353,8.36,11,8.36z M21,4.36 c-0.353,0-0.64,0.287-0.64,0.64S20.647,5.64,21,5.64S21.64,5.353,21.64,5S21.353,4.36,21,4.36z"></path></svg>
#                     </div>
#                 </caem-card>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 <caem-card color-scheme="" cta-type="local" data-autoid="caem--card" href="https://www.ibm.com/servers?lnk=ProdC" pictogram-placement="top" size="" target="_self">
#                     <caem-card-heading aria-level="3" data-autoid="caem--card-heading" role="heading" slot="heading">
#
#                         Server &amp; komputasi</caem-card-heading>
#                     <svg class="bx--card__pictogram" data-autoid="caem--card__pictogram" focusable="false" height="48" role="img" slot="pictogram" width="48">
#                         <use href="#storage--product"></use>
#                     </svg>
#                     <p>Jalankan beban kerja pada infrastruktur hybrid cloud</p>
#                     <caem-card-cta-footer color-scheme="" cta-type="local" data-autoid="caem--card-cta-footer" href="https://www.ibm.com/servers?lnk=ProdC" icon-placement="right" parent-href="https://www.ibm.com/servers?lnk=ProdC" slot="footer" target="_self">
#
#                     </caem-card-cta-footer>
#                     <div class="caem-card-svg-source">
# ...
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-xl-retina.ts=1718310858240.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-xl.ts=1718310858240.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-l-retina.ts=1718310858240.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-l.ts=1718310858240.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-m-retina.ts=1718310858240.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-m.ts=1718310858240.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-s-retina.ts=1718310858240.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-s.ts=1718310858240.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-xs-retina.ts=1718310858240.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/fe/64/universitychile0013846.component.card-xs.ts=1718310858240.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/card_1937905391/image"></dds-image-item>
#
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#
#         <dds-card-eyebrow aria-hidden="true" class="bx--card__eyebrow" slot="eyebrow">
#             Pelatihan dan keterampilan
#         </dds-card-eyebrow>
#         <dds-card-heading aria-level="3" class="bx--card__heading" role="heading" slot="heading">
#             Perkuat masa depan Anda di bidang teknologi dengan keterampilan kerja, kursus, dan kredensial—gratis
#         </dds-card-heading>
#
#         <dds-card-cta-footer aria-hidden="true" class="bx--card__footer-icon-size" cta-type="external" href="https://skillsbuild.org/" icon-placement="right" slot="footer" target="_blank">
#
#
#
#
#
#
#
#         </dds-card-cta-footer>
#     </dds-card-group-item>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <dds-card-group-item cta-type="local" href="https://www.ibm.com/impact" pictogram-placement="top" target="_self">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <dds-image alt="Pemandangan udara panel surya tersusun dalam baris grafis" class="" default-src="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/54/74/dji_0758.component.card-xl.ts=1713369765617.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/block_card/image" id="image--1009523838" slot="image">
#
#
#
#
#     <dds-image-item media="(min-width: 1312px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/54/74/dji_0758.component.card-xl-retina.ts=1713369765617.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/block_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1312px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/54/74/dji_0758.component.card-xl.ts=1713369765617.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/block_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/54/74/dji_0758.component.card-l-retina.ts=1713369765617.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/block_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 1056px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/54/74/dji_0758.component.card-l.ts=1713369765617.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/block_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/54/74/dji_0758.component.card-m-retina.ts=1713369765617.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/block_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 672px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/54/74/dji_0758.component.card-m.ts=1713369765617.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/block_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/54/74/dji_0758.component.card-s-retina.ts=1713369765617.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/block_card/image"></dds-image-item>
#     <dds-image-item media="(min-width: 481px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/54/74/dji_0758.component.card-s.ts=1713369765617.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/block_card/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px) and (min-resolution: 192dpi)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/54/74/dji_0758.component.card-xs-retina.ts=1713369765617.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/block_card/image"></dds-image-item>
#     <dds-image-item media="(max-width: 480px)" srcset="/content/dam/connectedassets-adobe-cms/worldwide-content/stock-assets/getty/image/photography/54/74/dji_0758.component.card-xs.ts=1713369765617.jpg/content/adobe-cms/id/id/homepage/jcr:content/root/table_of_contents/block_card_container/container/block_card/image"></dds-image-item>
#
#
#
#
#
#         </dds-image>
#
#
#
#
#
#
#
#
#
#         <dds-card-eyebrow aria-hidden="true" class="bx--card__eyebrow" slot="eyebrow">
#              Tanggung jawab sosial korporat
#         </dds-card-eyebrow>
#         <dds-card-heading aria-level="3" class="bx--card__heading" role="heading" slot="heading">
#             IBM bercita-cita untuk memberikan dampak positif bagi dunia, sebagai tempat bekerja dan tinggal
#         </dds-card-heading>
#
#         <dds-card-cta-footer aria-hidden="true" class="bx--card__footer-icon-size" cta-type="local" href="https://www.ibm.com/impact" icon-placement="right" slot="footer" target="_self">
#
#
#
#
#
#
#
#         </dds-card-cta-footer>
#     </dds-card-group-item>
#
#
#
#
#
#
#
#
#
#
#                 </dds-card-group>
#
#
#
#
#
#
#
#
#
#
#
#
#
#         </dds-content-block-cards>
#     </dds-video-cta-container>
#
#
#
#
# </div>
#
#
#     </div>
#
# </dds-table-of-contents>
#
# </div>
# <div class="footer">
#
#
#
#
#     <dds-footer-container class="cmp-footer" data-autoid="dds--footer" data-children-count="0" data-cmp-is="footer" size="tall"></dds-footer-container>
#
#
# </div>
#
#
#     </div>
#
# </div>
#
#
# <dds-lightbox-video-player-container></dds-lightbox-video-player-container>
#
#
#
#
# <script src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlBundle.lc-f18a4324a5a49c7e62b64b3472dcf5ef-lc.min.js"></script>
#
#
#
#
#
#     <script src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-target-antiflicker.lc-36a1efb28e947b5873f4a28c2cf9d5eb-lc.min.js"></script>
# <script src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlStyles.lc-cd19d0e52a85d5565651eb2c6e160e41-lc.min.js"></script>
#
#
#
# <script async="" defer="" src="https://www.ibm.com/common/digitaladvisor/cm-app/latest/cm-app.min.js"></script>
#
#
#
#
#
#             <script src="https://1.www.s81c.com/common/carbon/web-components/version/v1.40.0/tag.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon/web-components/version/v1.40.0/code-snippet.min.js" type="module"></script>
#
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/footer.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/card-group.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/image.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/content-block.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/link-list.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/link-list-item-cta.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/table-of-contents.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/card-cta-footer.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/tag-group.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/button-cta.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/content-group-heading.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/lightbox-video-player.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/feature-section.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/content-block-cards.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/content-group.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/version/v1.44.0/video-cta-container.min.js" type="module"></script>
#
#
#             <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.13.1/link-list-item.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.13.1/brand-cta-section.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.13.1/paragraph.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.13.1/card.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.13.1/tile.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.13.1/leadspace.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.13.1/card-group.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.13.1/intro-section.min.js" type="module"></script>
#
#             <script src="https://1.www.s81c.com/common/carbon/carbon-for-aem/version/v0.13.1/heading.min.js" type="module"></script>
#
#
#     <script id="anti-flicker-script" type="module">
#         document.getElementById('anti-flicker-style').remove();
#         document.getElementById('anti-flicker-script').remove();
#     </script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script src="/SAjXVw/rp/FH/ISbE/ON6P0nhR_f/5VO3JfmXGQS93w/P2sgAg/AV0/RXiQxDTo" type="text/javascript"></script><link href="/_sec/cp_challenge/sec-4-5.css" rel="stylesheet" type="text/css"/>
#                                         <script async="" defer="" src="/_sec/cp_challenge/sec-cpt-4-5.js"></script>
#                                         <div id="sec-overlay" style="display:none;">
#                                         <div id="sec-container">
#                                         </div>
#                                       </div>
# </body></html>

# %%
#1. scrape all of the links in the webpage
for link in soup.find_all('a', href=True):
    print(link.get('href'))
# Out:
# https://www.ibm.com/cloud?lnk=intro

# %%
#2. scrape the images tags
for image in soup.find_all('img'):
    print(image)
    print(image.get('src'))
# Out:
# <img alt="Potret para konsultan IBM" class="bx--image__img" id="image-1653134387" loading="lazy" src="/content/dam/adobe-cms/default-images/home-consultants.component.crop-16by9-xl.ts=1695238692853.jpg/content/adobe-cms/id/id/homepage/_jcr_content/root/table_of_contents/simple_image"/>
# /content/dam/adobe-cms/default-images/home-consultants.component.crop-16by9-xl.ts=1695238692853.jpg/content/adobe-cms/id/id/homepage/_jcr_content/root/table_of_contents/simple_image

# %%
#3. scrape data from HTML tables
# Notes. we will use the another source that contains the html table

#3.1 Get the source
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

#3.2 Get the contents of webpage in text format
datas = requests.get(url).text

#3.3 create a beautifulsoup object
soup = BeautifulSoup(datas, 'html5lib')

#3.3 Find the html table in the webpage
table = soup.find('table') # in html, table is represented by the tag <table>

#get all rows from the table
for row in table.find_all('tr'): #in html, row is represented by tag <tr>
    cols = row.find_all('td') #in html, column is represented by tag <td>
    color_name = cols[2].string #store the value in column 3 as color_name
    color_code =cols[3].text #store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->Hex Code#RRGGBB
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF
